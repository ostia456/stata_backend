# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
def type_detection(data):
    list_columns=data.columns.tolist()

# %%
df.dtypes.apply(pd.DataFrame.loc[df.columns])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.dtypes.apply(pd.DataFrame.loc[df.columns])
#
# TypeError: 'property' object is not subscriptable

# %%
# Out:
# numpy.float64

# %%
df.columns.tolist()
# Out:
# ['150', '4', 'setosa', 'versicolor', 'virginica']
